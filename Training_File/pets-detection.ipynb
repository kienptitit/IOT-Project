# %%
# !pip install ultralytics

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="43CdDoSQiPcJBwXAaLwo")
project = rf.workspace("ptit-2htcv").project("plants-pets-detection")
dataset = project.version(3).download("yolov4scaled")

# %%
import yaml
with open("/kaggle/working/Plants-Pets-Detection-3/data.yaml","r") as f:
    data = yaml.safe_load(f)
data['train'] = '/kaggle/working/Plants-Pets-Detection-3/train'
data['test'] = '/kaggle/working/Plants-Pets-Detection-3/test'
data['valid'] = '/kaggle/working/Plants-Pets-Detection-3/valid'
with open("/kaggle/working/Plants-Pets-Detection-3/data.yaml", 'w') as file:
    yaml.dump(data, file)

# %%
# !wandb disabled

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
